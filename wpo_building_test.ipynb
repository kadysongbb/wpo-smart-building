# %%
import os

import gym
import numpy as np
import matplotlib.pyplot as plt

from stable_baselines import *
from stable_baselines.bench import Monitor
from stable_baselines.common.vec_env import DummyVecEnv, VecNormalize
from stable_baselines import results_plotter

from stable_baselines.ddpg.noise import NormalActionNoise, OrnsteinUhlenbeckActionNoise

# %% [markdown]
# # Training

# %%
from stable_baselines.common.policies import MlpPolicy, CnnPolicy, FeedForwardPolicy
import sinergym

# Create log dir
log_dir = "tmp/"
os.makedirs(log_dir, exist_ok=True)

# Customize value network 
class CustomPolicy(FeedForwardPolicy):
    def __init__(self, *args, **kwargs):
        super(CustomPolicy, self).__init__(*args, **kwargs,
                                           net_arch=[dict(vf=[10, 7, 5])],
                                           feature_extraction="mlp")
        
# Create and wrap the environmentc
env = gym.make('Eplus-5Zone-mixed-discrete-v1')
env = Monitor(env, log_dir, allow_early_resets=True)
env = DummyVecEnv(([lambda: env]))

model = ACER(MlpPolicy, env, verbose=1)

# Train the agent
time_steps = 50000
model.learn(total_timesteps=time_steps)
# Out:
# [2023-01-03 23:59:02,301] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 23:59:02,301] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 23:59:02,301] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Updating idf Site:Location and SizingPeriod:DesignDay(s) to weather and ddy file...
# [2023-01-03 23:59:02,305] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 23:59:02,305] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 23:59:02,305] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Setting up extra configuration in building model if exists...
# [2023-01-03 23:59:03,486] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 23:59:03,486] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 23:59:03,486] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 23:59:03,505] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run1
# [2023-01-03 23:59:03,505] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run1
# [2023-01-03 23:59:03,505] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run1
# ----------------------------------
# | avg_norm_adj        | 21.3     |
# | avg_norm_g          | 214      |
# | avg_norm_grads_f    | 203      |
# | avg_norm_k          | 3.16     |
# | avg_norm_k_dot_g    | 214      |
# | entropy             | 48.4     |
# | explained_variance  | 6.4e-05  |
# | fps                 | 0        |
# | loss                | 99.7     |
# | loss_bc             | -0       |
# | loss_f              | -49.3    |
# | loss_policy         | -49.3    |
# | loss_q              | 299      |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 38.7     |
# | norm_grads_policy   | 29.9     |
# | norm_grads_q        | 24.6     |
# | total_timesteps     | 0        |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 8.99     |
# | avg_norm_g          | 89.8     |
# | avg_norm_grads_f    | 84.9     |
# | avg_norm_k          | 3.21     |
# | avg_norm_k_dot_g    | 93.3     |
# | entropy             | 48       |
# | explained_variance  | -0.0325  |
# | fps                 | 783      |
# | loss                | 2.63     |
# | loss_bc             | -0       |
# | loss_f              | -20.5    |
# | loss_policy         | -20.5    |
# | loss_q              | 47.2     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 19.6     |
# | norm_grads_policy   | 14.3     |
# | norm_grads_q        | 13.4     |
# | total_timesteps     | 2000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 5.81     |
# | avg_norm_g          | 59.3     |
# | avg_norm_grads_f    | 56.2     |
# | avg_norm_k          | 3.18     |
# | avg_norm_k_dot_g    | 59.6     |
# | entropy             | 47.5     |
# | explained_variance  | -0.431   |
# | fps                 | 797      |
# | loss                | -4.1     |
# | loss_bc             | -0       |
# | loss_f              | -13.6    |
# | loss_policy         | -13.6    |
# | loss_q              | 20       |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 31.8     |
# | norm_grads_policy   | 9.39     |
# | norm_grads_q        | 30.3     |
# | total_timesteps     | 4000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0314   |
# | avg_norm_g          | 21.2     |
# | avg_norm_grads_f    | 21.2     |
# | avg_norm_k          | 3.2      |
# | avg_norm_k_dot_g    | 21.8     |
# | entropy             | 46.7     |
# | explained_variance  | -0.308   |
# | fps                 | 804      |
# | loss                | 6.88     |
# | loss_bc             | -0       |
# | loss_f              | 4.91     |
# | loss_policy         | 4.91     |
# | loss_q              | 4.87     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 22.2     |
# | norm_grads_policy   | 21.5     |
# | norm_grads_q        | 5.42     |
# | total_timesteps     | 6000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 3.37     |
# | avg_norm_g          | 35.1     |
# | avg_norm_grads_f    | 33.3     |
# | avg_norm_k          | 3.25     |
# | avg_norm_k_dot_g    | 36.5     |
# | entropy             | 45.1     |
# | explained_variance  | 0.278    |
# | fps                 | 806      |
# | loss                | -3.94    |
# | loss_bc             | -0       |
# | loss_f              | -8.61    |
# | loss_policy         | -8.61    |
# | loss_q              | 10.3     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 9.14     |
# | norm_grads_policy   | 5.82     |
# | norm_grads_q        | 7.06     |
# | total_timesteps     | 8000     |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 5.32     |
# | avg_norm_g          | 53.2     |
# | avg_norm_grads_f    | 50.1     |
# | avg_norm_k          | 3.28     |
# | avg_norm_k_dot_g    | 58.6     |
# | entropy             | 44.9     |
# | explained_variance  | -0.114   |
# | fps                 | 808      |
# | loss                | -3.65    |
# | loss_bc             | -0       |
# | loss_f              | -9.84    |
# | loss_policy         | -9.84    |
# | loss_q              | 13.3     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 24.7     |
# | norm_grads_policy   | 7.14     |
# | norm_grads_q        | 23.6     |
# | total_timesteps     | 10000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 76.5     |
# | avg_norm_grads_f    | 76.5     |
# | avg_norm_k          | 3.18     |
# | avg_norm_k_dot_g    | 76.4     |
# | entropy             | 45.1     |
# | explained_variance  | -0.00414 |
# | fps                 | 810      |
# | loss                | 45.3     |
# | loss_bc             | -0       |
# | loss_f              | 19.4     |
# | loss_policy         | 19.4     |
# | loss_q              | 52.8     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 1.16e+03 |
# | norm_grads_policy   | 23       |
# | norm_grads_q        | 1.16e+03 |
# | total_timesteps     | 12000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.0298   |
# | avg_norm_g          | 29.4     |
# | avg_norm_grads_f    | 29.4     |
# | avg_norm_k          | 3.27     |
# | avg_norm_k_dot_g    | 31.2     |
# | entropy             | 44.1     |
# | explained_variance  | -0.0048  |
# | fps                 | 812      |
# | loss                | 7.71     |
# | loss_bc             | -0       |
# | loss_f              | 5.65     |
# | loss_policy         | 5.65     |
# | loss_q              | 5.01     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 176      |
# | norm_grads_policy   | 9.34     |
# | norm_grads_q        | 176      |
# | total_timesteps     | 14000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 20.4     |
# | avg_norm_g          | 198      |
# | avg_norm_grads_f    | 186      |
# | avg_norm_k          | 3.29     |
# | avg_norm_k_dot_g    | 221      |
# | entropy             | 40.5     |
# | explained_variance  | -0.0293  |
# | fps                 | 815      |
# | loss                | 76.4     |
# | loss_bc             | -0       |
# | loss_f              | -39.7    |
# | loss_policy         | -39.7    |
# | loss_q              | 233      |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 271      |
# | norm_grads_policy   | 268      |
# | norm_grads_q        | 37.9     |
# | total_timesteps     | 16000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 8.54     |
# | avg_norm_g          | 81.1     |
# | avg_norm_grads_f    | 76.8     |
# | avg_norm_k          | 3        |
# | avg_norm_k_dot_g    | 77.8     |
# | entropy             | 42.4     |
# | explained_variance  | -0.00668 |
# | fps                 | 819      |
# | loss                | 15.6     |
# | loss_bc             | -0       |
# | loss_f              | -19.3    |
# | loss_policy         | -19.3    |
# | loss_q              | 70.5     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 33.4     |
# | norm_grads_policy   | 21.2     |
# | norm_grads_q        | 25.8     |
# | total_timesteps     | 18000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 27.5     |
# | avg_norm_g          | 263      |
# | avg_norm_grads_f    | 246      |
# | avg_norm_k          | 3.26     |
# | avg_norm_k_dot_g    | 300      |
# | entropy             | 42       |
# | explained_variance  | 0.025    |
# | fps                 | 822      |
# | loss                | 116      |
# | loss_bc             | -0       |
# | loss_f              | -45.6    |
# | loss_policy         | -45.6    |
# | loss_q              | 325      |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 312      |
# | norm_grads_policy   | 309      |
# | norm_grads_q        | 43.6     |
# | total_timesteps     | 20000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 10.3     |
# | avg_norm_g          | 160      |
# | avg_norm_grads_f    | 153      |
# | avg_norm_k          | 4.28     |
# | avg_norm_k_dot_g    | 196      |
# | entropy             | 13.5     |
# | explained_variance  | 0.00809  |
# | fps                 | 826      |
# | loss                | 94.2     |
# | loss_bc             | -0       |
# | loss_f              | -14.8    |
# | loss_policy         | -14.8    |
# | loss_q              | 218      |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 319      |
# | norm_grads_policy   | 313      |
# | norm_grads_q        | 64.3     |
# | total_timesteps     | 22000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 20.8     |
# | avg_norm_g          | 200      |
# | avg_norm_grads_f    | 187      |
# | avg_norm_k          | 3.41     |
# | avg_norm_k_dot_g    | 242      |
# | entropy             | 4.88     |
# | explained_variance  | 0.00934  |
# | fps                 | 830      |
# | loss                | 63.1     |
# | loss_bc             | -0       |
# | loss_f              | -6.37    |
# | loss_policy         | -6.37    |
# | loss_q              | 139      |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 54.4     |
# | norm_grads_policy   | 6.21     |
# | norm_grads_q        | 54.1     |
# | total_timesteps     | 24000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 32.2     |
# | avg_norm_grads_f    | 32.2     |
# | avg_norm_k          | 1.96     |
# | avg_norm_k_dot_g    | 12.4     |
# | entropy             | 12       |
# | explained_variance  | 0.209    |
# | fps                 | 834      |
# | loss                | 14.6     |
# | loss_bc             | -0       |
# | loss_f              | 3.11     |
# | loss_policy         | 3.11     |
# | loss_q              | 23.2     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 56.6     |
# | norm_grads_policy   | 51.1     |
# | norm_grads_q        | 24.2     |
# | total_timesteps     | 26000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.049    |
# | avg_norm_g          | 9.57     |
# | avg_norm_grads_f    | 9.54     |
# | avg_norm_k          | 3.62     |
# | avg_norm_k_dot_g    | 9.17     |
# | entropy             | 33       |
# | explained_variance  | -0.133   |
# | fps                 | 833      |
# | loss                | 3.58     |
# | loss_bc             | -0       |
# | loss_f              | 2.3      |
# | loss_policy         | 2.3      |
# | loss_q              | 3.22     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 23.7     |
# | norm_grads_policy   | 9.04     |
# | norm_grads_q        | 21.9     |
# | total_timesteps     | 28000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0.719    |
# | avg_norm_g          | 39.5     |
# | avg_norm_grads_f    | 39.1     |
# | avg_norm_k          | 3.48     |
# | avg_norm_k_dot_g    | 48.1     |
# | entropy             | 22.4     |
# | explained_variance  | -0.37    |
# | fps                 | 824      |
# | loss                | 5.99     |
# | loss_bc             | -0       |
# | loss_f              | -1.9     |
# | loss_policy         | -1.9     |
# | loss_q              | 16.2     |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 76.2     |
# | norm_grads_policy   | 14.3     |
# | norm_grads_q        | 74.9     |
# | total_timesteps     | 30000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 0        |
# | avg_norm_g          | 18.9     |
# | avg_norm_grads_f    | 18.9     |
# | avg_norm_k          | 2.94     |
# | avg_norm_k_dot_g    | 19       |
# | entropy             | 20.9     |
# | explained_variance  | -4.56    |
# | fps                 | 824      |
# | loss                | 31       |
# | loss_bc             | -0       |
# | loss_f              | 6.7      |
# | loss_policy         | 6.7      |
# | loss_q              | 49       |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 623      |
# | norm_grads_policy   | 16.8     |
# | norm_grads_q        | 623      |
# | total_timesteps     | 32000    |
# ----------------------------------
# ----------------------------------
# | avg_norm_adj        | 6.65     |
# | avg_norm_g          | 56.7     |
# | avg_norm_grads_f    | 52.9     |
# | avg_norm_k          | 3        |
# | avg_norm_k_dot_g    | 60.3     |
# | entropy             | 21.7     |
# | explained_variance  | 0.0502   |
# | fps                 | 824      |
# | loss                | 171      |
# | loss_bc             | -0       |
# | loss_f              | -20.3    |
# | loss_policy         | -20.3    |
# | loss_q              | 382      |
# | mean_episode_length | 0        |
# | mean_episode_reward | 0        |
# | norm_grads          | 2.24e+03 |
# | norm_grads_policy   | 232      |
# | norm_grads_q        | 2.23e+03 |
# | total_timesteps     | 34000    |
# ----------------------------------
# [2023-01-03 23:59:47,781] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 23:59:47,781] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 23:59:47,781] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-03 23:59:47,783] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 23:59:47,783] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 23:59:47,783] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-03 23:59:47,806] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run2
# [2023-01-03 23:59:47,806] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run2
# [2023-01-03 23:59:47,806] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run2
# -----------------------------------
# | avg_norm_adj        | 3.77      |
# | avg_norm_g          | 33.8      |
# | avg_norm_grads_f    | 31.7      |
# | avg_norm_k          | 2.98      |
# | avg_norm_k_dot_g    | 34.5      |
# | entropy             | 26.4      |
# | explained_variance  | -2.84e-05 |
# | fps                 | 789       |
# | loss                | 39.1      |
# | loss_bc             | -0        |
# | loss_f              | -12.2     |
# | loss_policy         | -12.2     |
# | loss_q              | 103       |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 49.4      |
# | norm_grads_policy   | 31.6      |
# | norm_grads_q        | 37.9      |
# | total_timesteps     | 36000     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 6.8       |
# | avg_norm_g          | 67.1      |
# | avg_norm_grads_f    | 63.4      |
# | avg_norm_k          | 3.15      |
# | avg_norm_k_dot_g    | 68.5      |
# | entropy             | 34.1      |
# | explained_variance  | 0.074     |
# | fps                 | 791       |
# | loss                | 10.3      |
# | loss_bc             | -0        |
# | loss_f              | -14.4     |
# | loss_policy         | -14.4     |
# | loss_q              | 50.1      |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 1.34e+03  |
# | norm_grads_policy   | 937       |
# | norm_grads_q        | 957       |
# | total_timesteps     | 38000     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.0025    |
# | avg_norm_g          | 64.3      |
# | avg_norm_grads_f    | 64.3      |
# | avg_norm_k          | 3.09      |
# | avg_norm_k_dot_g    | 61.6      |
# | entropy             | 38.1      |
# | explained_variance  | 0.242     |
# | fps                 | 785       |
# | loss                | 33.2      |
# | loss_bc             | -0        |
# | loss_f              | 13.6      |
# | loss_policy         | 13.6      |
# | loss_q              | 40        |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 1.68e+03  |
# | norm_grads_policy   | 46.4      |
# | norm_grads_q        | 1.68e+03  |
# | total_timesteps     | 40000     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.0594    |
# | avg_norm_g          | 30.1      |
# | avg_norm_grads_f    | 30        |
# | avg_norm_k          | 3.11      |
# | avg_norm_k_dot_g    | 30.1      |
# | entropy             | 38.7      |
# | explained_variance  | 0.692     |
# | fps                 | 786       |
# | loss                | 10.6      |
# | loss_bc             | -0        |
# | loss_f              | 5.62      |
# | loss_policy         | 5.62      |
# | loss_q              | 10.8      |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 2.52e+03  |
# | norm_grads_policy   | 19.1      |
# | norm_grads_q        | 2.52e+03  |
# | total_timesteps     | 42000     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0         |
# | avg_norm_g          | 43.2      |
# | avg_norm_grads_f    | 43.2      |
# | avg_norm_k          | 3.17      |
# | avg_norm_k_dot_g    | 43.4      |
# | entropy             | 18.6      |
# | explained_variance  | -5.61     |
# | fps                 | 787       |
# | loss                | 79.9      |
# | loss_bc             | -0        |
# | loss_f              | 10.7      |
# | loss_policy         | 10.7      |
# | loss_q              | 139       |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 3.39e+03  |
# | norm_grads_policy   | 18.7      |
# | norm_grads_q        | 3.39e+03  |
# | total_timesteps     | 44000     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.00261   |
# | avg_norm_g          | 201       |
# | avg_norm_grads_f    | 201       |
# | avg_norm_k          | 3.12      |
# | avg_norm_k_dot_g    | 199       |
# | entropy             | 32.6      |
# | explained_variance  | -13.4     |
# | fps                 | 785       |
# | loss                | 196       |
# | loss_bc             | -0        |
# | loss_f              | 40        |
# | loss_policy         | 40        |
# | loss_q              | 313       |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 3.81e+03  |
# | norm_grads_policy   | 110       |
# | norm_grads_q        | 3.81e+03  |
# | total_timesteps     | 46000     |
# -----------------------------------
# -----------------------------------
# | avg_norm_adj        | 0.207     |
# | avg_norm_g          | 24.3      |
# | avg_norm_grads_f    | 24.2      |
# | avg_norm_k          | 3.15      |
# | avg_norm_k_dot_g    | 24.2      |
# | entropy             | 41        |
# | explained_variance  | -0.295    |
# | fps                 | 786       |
# | loss                | 7.39      |
# | loss_bc             | -0        |
# | loss_f              | 3.85      |
# | loss_policy         | 3.85      |
# | loss_q              | 7.9       |
# | mean_episode_length | 3.5e+04   |
# | mean_episode_reward | -5.06e+04 |
# | norm_grads          | 230       |
# | norm_grads_policy   | 42.7      |
# | norm_grads_q        | 226       |
# | total_timesteps     | 48000     |
# -----------------------------------

# %% [markdown]
# # Testing

# %%
obs = env.reset()
total_power = 0
total_discomfort = 0
ndays = 50
for i in range(24*ndays):
    action, _states = model.predict(obs)
    obs, rewards, dones, info = env.step(action)
    dic = info[0]
    total_power += dic['total_power']
    if dic['temperatures'][0] > 26 or dic['temperatures'][0] < 20:
        total_discomfort += 0.25
print(total_power/ndays)
print(total_discomfort/ndays)
# Out:
# [2023-01-04 00:00:35,862] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-04 00:00:35,862] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-04 00:00:35,862] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus episode completed successfully.
# [2023-01-04 00:00:35,864] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-04 00:00:35,864] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-04 00:00:35,864] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:Creating new EnergyPlus simulation episode...
# [2023-01-04 00:00:35,888] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run3
# [2023-01-04 00:00:35,888] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run3
# [2023-01-04 00:00:35,888] EPLUS_ENV_5Zone-mixed-discrete-v1_MainThread_ROOT INFO:EnergyPlus working directory is in /Users/kady/Documents/Code-DR-TRPO/wpo-smart-building/Eplus-env-5Zone-mixed-discrete-v1-res3/Eplus-env-sub_run3
# 182658.4209873612
# 2.325
